# %%
# import numpy
import numpy as np

# seasons
Seasons = ["2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"]
Sdict = {"2015":0,"2016":1,"2017":2,"2018":3,"2019":4,"2020":5,"2021":6,"2022":7,"2023":8,"2024":9}

#Players
Players = ["Sachin","Rahul","Smith","Sami","Pollard","Morris","Samson","Dhoni","Kohli","Sky"]
Pdict = {"Sachin":0,"Rahul":1,"Smith":2,"Sami":3,"Pollard":4,"Morris":5,"Samson":6,"Dhoni":7,"Kohli":8,"Sky":9}

#Salaries
Sachin_Salary = [15946875,17718750,19490625,21262500,23024375,24806250,25244493,27849149,30453805,23500000]
Rahul_Salary = [12000000,25634727,16498372,13597206,13497605,13497652,10234567,13467902,13467952,196354782]
Smith_Salary = [34569752,45632198,10346792,23497000,34965210,10347950,15640000,34876500,24679530,42361500]
Sami_Salary = [45397520,43597500,20134900,34561203,52134904,31205642,321456890,12345678,3245647,32654896]
Pollard_Salary = [23456790,24563000,42350000,65123420,12458673,35426100,26486300,34597600,63140000,42361050]
Morris_Salary = [34561000,34860000,42653100,65423100,20314520,31420000,34510000,2642000,34520000,63420000]
Samson_Salary = [32465100,31500000,42165300,21546378,31446942,34165820,14562900,24593100,42583000,13458200]
Dhoni_Salary = [42518000,42163000,20144200,31040000,20159631,10000000,43576500,42658963,32145697,61234578]
Kohli_Salary= [21586000,32014500,30154789,3249100,42679000,26480000,32400000,62143000,25489633,34857622]
Sky_Salary = [62483314,52976000,34852000,64831860,42863000,21586300,62485000,42657000,65421893,35976200]

#Matrix
Salary = np.array([Sachin_Salary, Rahul_Salary, Smith_Salary, Sami_Salary, Pollard_Salary, Morris_Salary, Samson_Salary, Dhoni_Salary, Kohli_Salary, Sky_Salary])

#Games
Sachin_G = [80,77,82,82,73,82,58,78,6,35]
Rahul_G = [82,57,82,79,76,72,60,72,79,80]
Smith_G = [79,78,75,81,76,79,62,76,77,69]
Sami_G = [80,65,77,66,69,77,55,67,77,40]
Pollard_G = [82,82,82,79,82,78,54,76,71,41]
Morris_G = [70,69,67,77,70,77,57,74,79,44]
Samson_G = [78,64,80,78,45,80,60,70,62,80]
Dhoni_G = [35,35,80,74,82,78,66,81,81,27]
Kholi_G = [40,40,40,81,78,81,39,0,10,51]
Sky_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([Sachin_G, Rahul_G , Smith_G, Sami_G, Pollard_G, Morris_G, Samson_G, Dhoni_G, Kholi_G , Sky_G])

#Points
Sachin_PTS = [2832,2430,2323,2210,1970,2078,1616,2133,83,782]
Rahul_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
Smith_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
Sami_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
Pollard_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
Morris_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
Samson_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
Dhoni_PTS = [903,597,597,1361,1619,2026,852,0,159,904]
Kholi_PTS = [597,597,597,1361,1619,2026,1850,2280,2593,4532]
Sky_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([Sachin_PTS, Rahul_PTS , Smith_PTS, Sami_PTS, Pollard_PTS, Morris_PTS, Samson_PTS, Dhoni_PTS, Kholi_PTS, Sky_PTS])

# %%
Salary
# Out:
# array([[ 15946875,  17718750,  19490625,  21262500,  23024375,  24806250,
#          25244493,  27849149,  30453805,  23500000],
#        [ 12000000,  25634727,  16498372,  13597206,  13497605,  13497652,
#          10234567,  13467902,  13467952, 196354782],
#        [ 34569752,  45632198,  10346792,  23497000,  34965210,  10347950,
#          15640000,  34876500,  24679530,  42361500],
#        [ 45397520,  43597500,  20134900,  34561203,  52134904,  31205642,
#         321456890,  12345678,   3245647,  32654896],
#        [ 23456790,  24563000,  42350000,  65123420,  12458673,  35426100,
#          26486300,  34597600,  63140000,  42361050],
#        [ 34561000,  34860000,  42653100,  65423100,  20314520,  31420000,
#          34510000,   2642000,  34520000,  63420000],
#        [ 32465100,  31500000,  42165300,  21546378,  31446942,  34165820,
#          14562900,  24593100,  42583000,  13458200],
#        [ 42518000,  42163000,  20144200,  31040000,  20159631,  10000000,
# ...

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 80],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
Points
# Out:
# array([[2832, 2430, 2323, 2210, 1970, 2078, 1616, 2133,   83,  782],
#        [1653, 1426, 1779, 1688, 1619, 1312, 1129, 1170, 1245, 1154],
#        [2478, 2132, 2250, 2304, 2258, 2111, 1683, 2036, 2089, 1743],
#        [2122, 1881, 1978, 1504, 1943, 1970, 1245, 1920, 2112,  966],
#        [1292, 1443, 1695, 1624, 1503, 1784, 1113, 1296, 1297,  646],
#        [1572, 1561, 1496, 1746, 1678, 1438, 1025, 1232, 1281,  928],
#        [1258, 1104, 1684, 1781,  841, 1268, 1189, 1186, 1185, 1564],
#        [ 903,  597,  597, 1361, 1619, 2026,  852,    0,  159,  904],
#        [ 597,  597,  597, 1361, 1619, 2026, 1850, 2280, 2593, 4532],
#        [2040, 1397, 1254, 2386, 2045, 1941, 1082, 1463, 1028, 1331]])

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 80],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
Games[1]
# Out:
# array([82, 57, 82, 79, 76, 72, 60, 72, 79, 80])

# %%
Games[0,6]
# Out:
# np.int64(58)

# %%
Salary
# Out:
# array([[ 15946875,  17718750,  19490625,  21262500,  23024375,  24806250,
#          25244493,  27849149,  30453805,  23500000],
#        [ 12000000,  25634727,  16498372,  13597206,  13497605,  13497652,
#          10234567,  13467902,  13467952, 196354782],
#        [ 34569752,  45632198,  10346792,  23497000,  34965210,  10347950,
#          15640000,  34876500,  24679530,  42361500],
#        [ 45397520,  43597500,  20134900,  34561203,  52134904,  31205642,
#         321456890,  12345678,   3245647,  32654896],
#        [ 23456790,  24563000,  42350000,  65123420,  12458673,  35426100,
#          26486300,  34597600,  63140000,  42361050],
#        [ 34561000,  34860000,  42653100,  65423100,  20314520,  31420000,
#          34510000,   2642000,  34520000,  63420000],
#        [ 32465100,  31500000,  42165300,  21546378,  31446942,  34165820,
#          14562900,  24593100,  42583000,  13458200],
#        [ 42518000,  42163000,  20144200,  31040000,  20159631,  10000000,
# ...

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 80],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
Salary / Games
# Out:
# C:\Users\janha\AppData\Local\Temp\ipykernel_21724\1572766764.py:1: RuntimeWarning: divide by zero encountered in divide
#   Salary / Games
# array([[ 199335.9375    ,  230113.63636364,  237690.54878049,
#          259298.7804878 ,  315402.39726027,  302515.24390244,
#          435249.87931034,  357040.37179487, 5075634.16666667,
#          671428.57142857],
#        [ 146341.46341463,  449732.05263158,  201199.65853659,
#          172116.53164557,  177600.06578947,  187467.38888889,
#          170576.11666667,  187054.19444444,  170480.40506329,
#         2454434.775     ],
#        [ 437591.79746835,  585028.17948718,  137957.22666667,
#          290086.41975309,  460068.55263158,  130986.70886076,
#          252258.06451613,  458901.31578947,  320513.37662338,
#          613934.7826087 ],
#        [ 567469.        ,  670730.76923077,  261492.20779221,
#          523654.59090909,  755578.31884058,  405268.07792208,
#         5844670.72727273,  184263.85074627,   42151.25974026,
# ...

# %%
np.round(Salary//Games)
# Out:
# C:\Users\janha\AppData\Local\Temp\ipykernel_21724\3663165759.py:1: RuntimeWarning: divide by zero encountered in floor_divide
#   np.round(Salary//Games)
# array([[ 199335,  230113,  237690,  259298,  315402,  302515,  435249,
#          357040, 5075634,  671428],
#        [ 146341,  449732,  201199,  172116,  177600,  187467,  170576,
#          187054,  170480, 2454434],
#        [ 437591,  585028,  137957,  290086,  460068,  130986,  252258,
#          458901,  320513,  613934],
#        [ 567469,  670730,  261492,  523654,  755578,  405268, 5844670,
#          184263,   42151,  816372],
#        [ 286058,  299548,  516463,  824347,  151935,  454180,  490487,
#          455231,  889295, 1033196],
#        [ 493728,  505217,  636613,  849650,  290207,  408051,  605438,
#           35702,  436962, 1441363],
#        [ 416219,  492187,  527066,  276235,  698820,  427072,  242715,
#          351330,  686822,  168227],
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

#we are using this code to ognore unknown erroe cause by as updation on monthly basis

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Salary[0]
# Out:
# array([15946875, 17718750, 19490625, 21262500, 23024375, 24806250,
#        25244493, 27849149, 30453805, 23500000])

# %%
plt.plot(Salary[0])
plt.show()

# %%
plt.plot(Salary[0], ls = '--')

# %%
plt.plot(Salary[0], ls = '-.')

# %%
plt.plot(Salary[0], ls = ':')

# %%
plt.plot(Salary[0], ls = '--', color = 'green')

# %%
plt.plot(Salary[0], ls = '--', color = 'black', marker = '^')

# %%
plt.plot(Salary[0], ls = '--', color = 'green', marker = 'o')

# %%
plt.plot(Salary[0], ls = '--', color = 'green', marker = 'd')

# %%
plt.plot(Salary[0], ls = '--', color = 'green', marker = 's')

# %%
plt.plot(Salary[0], ls = '--', color = 'green', marker = 'o', ms = 10)

# %%
Sdict
# Out:
# {'2015': 0,
#  '2016': 1,
#  '2017': 2,
#  '2018': 3,
#  '2019': 4,
#  '2020': 5,
#  '2021': 6,
#  '2022': 7,
#  '2023': 8,
#  '2024': 9}

# %%
Pdict
# Out:
# {'Sachin': 0,
#  'Rahul': 1,
#  'Smith': 2,
#  'Sami': 3,
#  'Pollard': 4,
#  'Morris': 5,
#  'Samson': 6,
#  'Dhoni': 7,
#  'Kohli': 8,
#  'Sky': 9}

# %%
plt.plot(Salary[0], c = 'blue', ls = '--', marker = 's', ms = 7)
plt.xticks(list(range(0,10)), Seasons)
plt.show()

# %%
plt.plot(Salary[0], c = 'blue', ls = '--', marker = 's', ms = 7)
plt.xticks(list(range(0,10)), Seasons, rotation = 'vertical')
plt.show()

# %%
Salary[1]
# Out:
# array([ 12000000,  25634727,  16498372,  13597206,  13497605,  13497652,
#         10234567,  13467902,  13467952, 196354782])

# %%
plt.plot(Salary[1], c = 'purple', ls = ':', marker = 'o', ms = 10)
plt.show()

# %%
plt.plot(Salary[1], c = 'purple', ls = ':', marker = 'o', ms = 10, label = Players[1])
plt.show()

# %%
plt.plot(Salary[0], c = 'blue', ls = '--', marker = 's', ms = 7, label = Players[0])
plt.plot(Salary[1], c = 'purple', ls = ':', marker = 'o', ms = 10, label = Players[1])

plt.xticks(list(range(0,10)), Seasons, rotation = 'vertical')

plt.show()

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 80],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
plt.plot(Salary[0], c = 'blue', ls = '--', marker = 's', ms = 8, label = Players[0])
plt.plot(Salary[1], c = 'purple', ls = ':', marker = 'o', ms = 8, label = Players[1])
plt.plot(Salary[2], c = 'green', ls = ':', marker = '^', ms = 8, label = Players[2])

plt.xticks(list(range(0,10)), Seasons, rotation = 'vertical')

plt.show()

# %%
plt.plot(Salary[0], c = 'blue', ls = '--', marker = 's', ms = 8, label = Players[0])
plt.plot(Salary[1], c = 'purple', ls = ':', marker = 'o', ms = 8, label = Players[1])
plt.plot(Salary[2], c = 'green', ls = '--', marker = '^', ms = 8, label = Players[2])
plt.plot(Salary[3], c = 'red', ls = '-.', marker = 'd', ms = 8, label = Players[3])

plt.legend()
plt.xticks(list(range(0,10)), Seasons, rotation = 'vertical')
plt.show()

# %%
plt.plot(Salary[0], c = 'blue', ls = '--', marker = 's', ms = 8)
plt.plot(Salary[1], c = 'purple', ls = ':', marker = 'o', ms = 8)
plt.plot(Salary[2], c = 'green', ls = '--', marker = '^', ms = 8)
plt.plot(Salary[3], c = 'red', ls = '-.', marker = 'd', ms = 8)

plt.legend()
plt.xticks(list(range(0,10)), Seasons, rotation = 'vertical')
plt.show()

# %%
plt.plot(Salary[0], c = 'Green', ls = '--', marker = 's', ms = 7, label = Players[0])
plt.plot(Salary[1], c = 'Blue', ls = '--', marker = 'o', ms = 5, label = Players[1])
plt.plot(Salary[2], c = 'Green', ls = '--', marker = '^', ms = 8, label = Players[2])
plt.plot(Salary[3], c = 'Red', ls = '--', marker = 'd', ms = 8, label = Players[3])
plt.plot(Salary[4], c = 'Black', ls = '--', marker = 's', ms = 8, label = Players[4])
plt.plot(Salary[5], c = 'Blue', ls = '--', marker = 'o', ms = 8, label = Players[5])
plt.plot(Salary[6], c = 'Purple', ls = '--', marker = '^', ms = 8, label = Players[6])
plt.plot(Salary[7], c = 'Black', ls = '--', marker = 'd', ms = 8, label = Players[7])
plt.plot(Salary[8], c = 'Red', ls = '--', marker = 'o', ms = 8, label = Players[8])
plt.plot(Salary[9], c = 'Green', ls = '--', marker = 'd', ms = 8, label = Players[9])

plt.legend(loc = 'lower right',bbox_to_anchor=(0.5,1))
plt.xticks(list(range(0,10)), Seasons, rotation = 'vertical')

plt.show()
