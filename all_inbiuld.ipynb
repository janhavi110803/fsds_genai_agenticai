# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
x = math.sqrt(25)
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(3.87))
# Out:
# 3

# %%
print(math.ceil(3.87))
# Out:
# 4

# %%
x = math.pow(10,11)
x
# Out:
# 100000000000.0

# %%
import math as m

# %%
m.sqrt(10)
m
# Out:
# <module 'math' (built-in)>

# %%
m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
x = input()
x
# Out:
#  4
# '4'

# %%
x = input()
y = input()

z = x + y
print(z)
# Out:
#  4
#  5
# 45

# %%
type(y)
# Out:
# str

# %%
type(x)
# Out:
# str

# %%
x1 = input('username :')
y1 = input('password :')
z1 = x1 + y1
print(z1)
# Out:
# username : janhavi
# password : 1234
# janhavi1234

# %%
x1 = input('Enter the 1st number')
a1 = int(x1)
y1 = input('Enter the 2nd number')
b1 = int(y1)
z1 = a1 + b1
print(z1)
# Out:
# Enter the 1st number 10
# Enter the 2nd number 12
# 22

# %%
x2 = int(input('Enter the 1st number :'))
y2 = int(input('Enter the 2st number :'))
z2 = x2 + y2
z2
# Out:
# Enter the 1st number : 10
# Enter the 2st number : 10
# 20
