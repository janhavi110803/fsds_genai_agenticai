# %%
a = 5
b = 4
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b > 2
# Out:
# True

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x = not x
x
# Out:
# True

# %%
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0b11110)
# Out:
# 30

# %%
0o31
# Out:
# 25

# %%
0b11001
# Out:
# 25

# %%
int(0b11001)
# Out:
# 25

# %%
bin(17)
# Out:
# '0b10001'

# %%
oct(25)
# Out:
# '0o31'

# %%
0o31
# Out:
# 25

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
0x19
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
0xa
# Out:
# 10

# %%
0xb
# Out:
# 11

# %%
hex(1)
# Out:
# '0x1'

# %%
0x19
# Out:
# 25

# %%
0x15
# Out:
# 21

# %%
a = 5
b = 6

# %%
a = b
b = a
print(a)
print(b)
# Out:
# 6
# 6

# %%
a1 = 7
b1 = 8
temp = a1
a1 = b1
b1 = temp

print(a1)
print(b1)
# Out:
# 8
# 7

# %%
a2 = 5
b2 = 6

# %%
a2 = a2 + b2
b2 = a2 - b2
a2 = a2 - b2

print(a2)
print(b2)
# Out:
# 6
# 5

# %%
a2 , b2
# Out:
# (6, 5)

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
a2, b2 = b2 , a2 
print(a2)
print(b2)
# Out:
# 5
# 6
