# %%
l = [100, 40, 30, 20, 15, 10]
l
# Out:
# [100, 40, 30, 20, 15, 10]

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l.append(0)
l
# Out:
# [100, 40, 30, 20, 15, 10, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True
