# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image # python imaging library

# %%
img = Image.open(r'C:\Users\janha\OneDrive\Pictures\Screenshots\Screenshot (11).png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1178x634>

# %%
type(img)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img_arr = np.asarray(img)
img_arr
# Out:
# array([[[254, 105,  61, 255],
#         [254, 104,  62, 255],
#         [254, 104,  64, 255],
#         ...,
#         [  3,  26,  55, 255],
#         [  2,  26,  54, 255],
#         [  2,  25,  54, 255]],
#
#        [[255, 106,  60, 255],
#         [254, 105,  61, 255],
#         [254, 105,  63, 255],
#         ...,
#         [  2,  25,  53, 255],
#         [  2,  25,  53, 255],
#         [  2,  24,  52, 255]],
#
#        [[254, 107,  58, 255],
#         [254, 106,  59, 255],
#         [254, 105,  61, 255],
#         ...,
#         [  1,  24,  52, 255],
#         [  1,  23,  51, 255],
#         [  1,  23,  51, 255]],
#
#        ...,
#
#        [[  5,  26,  55, 255],
#         [ 10,  26,  55, 255],
#         [ 23,  36,  64, 255],
#         ...,
#         [  0,   9,  22, 255],
#         [  1,   9,  22, 255],
#         [  1,   9,  20, 255]],
#
#        [[  5,  28,  56, 255],
#         [ 13,  30,  57, 255],
#         [ 29,  42,  68, 255],
#         ...,
#         [  2,   8,  21, 255],
# ...
