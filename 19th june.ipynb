# %%
i = 
i
# Out:
#   Cell In[1], line 1
#     i =
#         ^
# SyntaxError: invalid syntax

# %%
i = 32
i
# Out:
# 32

# %%
type(i)
# Out:
# int

# %%
f = 110.32
f
# Out:
# 110.32

# %%
type(f)
# Out:
# float

# %% [markdown]
# f1 = 1f0
# f1

# %%
f2 = 1e1
f1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 f2 = 1e1
# ----> 2 f1
#
# NameError: name 'f1' is not defined

# %%
f2 = 1e1
f2
# Out:
# 10.0

# %%
f3 = 1e2
f3
# Out:
# 100.0

# %%
f4 = 1e2
f4
# Out:
# 100.0

# %%
f4 = 1e3
f4
# Out:
# 1000.0

# %%
f5 = 1e4
f5
# Out:
# 10000.0

# %%
a = 10
b = 20

a+b
# Out:
# 30

# %%
a - b
# Out:
# -10

# %%
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
print(10)
print(10,20)
print("python")
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(add)
# Out:
# 50

# %%
num1 = 20
num2 = 30
add = num1 + num2
print("The addition of num1 and num2 is =" , add)
# Out:
# The addition of num1 and num2 is = 50

# %%
num1 = 20
num2 = 30
add = num1 + num2
print('The addition of' num1 'and' num2 'is' = , add)
# Out:
#   Cell In[19], line 4
#     print('The addition of' num1 'and' num2 'is' = , add)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
num1 = 20
num2 = 30
add = num1 + num2
print('The addition of' ,num1, 'and' ,num2, 'is' '=' , add)
# Out:
# The addition of 20 and 30 is= 50

# %%
num1 = 10
num2 = 30
add = num1 + num2 
print('yhe addition of {} and {} is = {}' . format(num1,num2,add))
# Out:
# yhe addition of 10 and 30 is = 40

# %%
num1 = 10
num2 = 30
num3 = 20
add = num1 + num2 + num3
print('The addition of {} and {} and {} is = {}' . format(num1,num2,num3,add))
# Out:
# The addition of 10 and 30 and 20 is = 60

# %%
c = 1 + 2j
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
c = 5 + 10j
d = 10 + 20j
print(c + d)
print(c - d)
# Out:
# (15+30j)
# (-5-10j)

# %%
a = 5.3
type(a)
# Out:
# float

# %%
def team():
    print(team)

# %%
c2 = 5 + 10j 
c2
# Out:
# (5+10j)

# %%
b = True
b
# Out:
# True

# %%
b1 = False
b1
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
True- False
# Out:
# 1

# %%
False- True
# Out:
# -1

# %%
True-True*False
# Out:
# 1
