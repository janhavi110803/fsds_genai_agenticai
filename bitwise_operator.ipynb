# %%
~12
# Out:
# -13

# %%
~46
# Out:
# -47

# %%
~54
# Out:
# -55

# %%
~10
# Out:
# -11

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
12 ^ 13
# Out:
# 1

# %%
25 ^ 30
# Out:
# 7

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
bin (7)
# Out:
# '0b111'

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(10)
# Out:
# '0b1010'

# %%
10 << 1
# Out:
# 20

# %%
10 << 2
# Out:
# 40

# %%
10 >> 2
# Out:
# 2

# %%
10 >> 3
# Out:
# 1

# %%
bin(20)
# Out:
# '0b10100'

# %%
20 >> 4
# Out:
# 1
