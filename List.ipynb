# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
l = []

l
# Out:
# []

# %% [raw]
# type(l)

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10, 10]

# %%
l
# Out:
# [10, 10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 10, 20, 20, 20]

# %%
len(l)
# Out:
# 5

# %%
l.append(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l.append(10,20)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

l
# Out:
# [10, 10, 20, 20, 20, 20, 30, 40, 50]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100

# %%
l
# Out:
# [10, 10, 20, 20, 20, 20, 30, 40, 50]

# %%
l[0] = 100
l
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, 50]

# %%
l[-1] = -50
l
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l1 = l.copy()
l1
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
print(l)
print(l1)
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l == l1
# Out:
# True

# %%
id(l) == id(l1)
# Out:
# False

# %%
id(l) != id(l1)
# Out:
# True

# %%
l
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l.count(20)
# Out:
# 4

# %%
len(l1)
# Out:
# 9

# %%
l1.clear()
l1
# Out:
# []

# %%
del l1
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 del l1
# ----> 2 l1
#
# NameError: name 'l1' is not defined

# %%
l
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l2 = []

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1=2j)
l2.append(9.3)
# Out:
#   Cell In[30], line 4
#     l2.append(1=2j)
#               ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1=2j)
l2.append(9.3)
l2
# Out:
#   Cell In[31], line 4
#     l2.append(1=2j)
#               ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(9.3)
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 l2.append(9)
#       2 l2.append('nit')
#       3 l2.append(True)
#
# NameError: name 'l2' is not defined

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(9.3)
l2
# Out:
# [9, 'nit', True, (1+2j), 9.3]

# %%
print(l)
print(l2)
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]
# [9, 'nit', True, (1+2j), 9.3]

# %%
l.index(100)
# Out:
# 0

# %%
l.index(20)
# Out:
# 2

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 9.3]

# %%
l2[1]
# Out:
# 'nit'

# %%
l2[1][0]
# Out:
# 'n'

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 9.3]

# %% [raw]
# print(l2[1][0])

# %%
print(l2[1])
# Out:
# nit

# %%
print(l2[1][0])
print(l2[1][1])
print(l2[1][2])
# Out:
# n
# i
# t

# %%
l
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l[:]
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l[3:]
# Out:
# [20, 20, 20, 30, 40, -50]

# %%
l[:10]
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50]

# %%
l[0:8:3]
# Out:
# [100, 20, 30]

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 9.3]

# %%
l2[1:6:2]
# Out:
# ['nit', (1+2j)]

# %%
l.insert(15,2)
l
# Out:
# [100, 10, 20, 20, 20, 20, 30, 40, -50, 2]

# %%
l.insert(2,15)
l
# Out:
# [100, 10, 15, 20, 20, 20, 20, 30, 40, -50, 2]

# %%
l.pop()
# Out:
# 2

# %%
l
# Out:
# [100, 10, 15, 20, 20, 20, 20, 30, 40, -50]

# %%
l.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
l.pop()
# Out:
# -50

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 9.3]

# %%
l2.pop(3)
# Out:
# (1+2j)

# %%
l2
# Out:
# [9, 'nit', True, 9.3]

# %%
l2.remove('nit')
l2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 l2.remove('nit')
#       2 l2
#
# ValueError: list.remove(x): x not in list

# %%
l2
# Out:
# [9, True, 9.3]

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l = []
l
# Out:
# []

# %%
l = [100, 10, 15, 20, 30, 40]
l
# Out:
# [100, 10, 15, 20, 30, 40]

# %%
for i in l:
    print(i)
# Out:
# 100
# 10
# 15
# 20
# 30
# 40

# %%
l
# Out:
# [100, 10, 15, 20, 30, 40]

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 100)
# (1, 10)
# (2, 15)
# (3, 20)
# (4, 30)
# (5, 40)

# %%
print(l)
print(l2)
# Out:
# [100, 10, 15, 20, 30, 40]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 print(l)
# ----> 2 print(l2)
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [100, 10, 15, 20, 30, 40]

# %%
l1 = [9, True, 9.3]
l1
# Out:
# [9, True, 9.3]

# %%
print(l)
print(l1)
# Out:
# [100, 10, 15, 20, 30, 40]
# [9, True, 9.3, 100, 10, 15, 20, 30, 40, 100, 10, 15, 20, 30, 40]

# %%
l1.extend(l)
l1
# Out:
# [9,
#  True,
#  9.3,
#  100,
#  10,
#  15,
#  20,
#  30,
#  40,
#  100,
#  10,
#  15,
#  20,
#  30,
#  40,
#  100,
#  10,
#  15,
#  20,
#  30,
#  40,
#  100,
#  10,
#  15,
#  20,
#  30,
#  40]

# %%
l1.clear()
l1
# Out:
# []

# %%
l.clear()
l
# Out:
# []

# %%
l = [100, 10, 15, 20, 30, 40]
l
# Out:
# [100, 10, 15, 20, 30, 40]

# %%
l2 = [9, True, 9.3]
l2
# Out:
# [9, True, 9.3]

# %%
print(l)
print(l2)
# Out:
# [100, 10, 15, 20, 30, 40]
# [9, True, 9.3]

# %%
l2.extend(l)
l2
# Out:
# [9, True, 9.3, 100, 10, 15, 20, 30, 40]

# %%
l.extend(l2)
l
# Out:
# [100, 10, 15, 20, 30, 40, 9, True, 9.3, 100, 10, 15, 20, 30, 40]

# %%
l.clear()
l
# Out:
# []

# %%
l = [100, 15, 10, 20, 30, 40]
l
# Out:
# [100, 15, 10, 20, 30, 40]

# %%
l.sort()
l
# Out:
# [10, 15, 20, 30, 40, 100]

# %%
l.sort(reverse = True)
l
# Out:
# [100, 40, 30, 20, 15, 10]

# %%
l2
# Out:
# [9, True, 9.3, 100, 10, 15, 20, 30, 40]

# %%
l3 = [1, 2.3, 'nit', True]
l3
# Out:
# [1, 2.3, 'nit', True]

# %%
l3.sort()
l3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l3.sort()
#       2 l3
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l4 = ['t', 'z', 'a', 'f']
l4
# Out:
# ['t', 'z', 'a', 'f']

# %%
l4.sort()
l4
# Out:
# ['a', 'f', 't', 'z']

# %%
l4.reverse()
l4
# Out:
# ['z', 't', 'f', 'a']
