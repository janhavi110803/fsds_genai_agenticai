# %%
print(id(p))
print(id(q))
print(id(r))
# Out:
# 140731343152648
# 140731343152648
# 140731343152648

# %%
s = "hello world"
s
# Out:
# 'hello world'

# %%
len(s)
# Out:
# 11

# %%
s
# Out:
# 'hello world'

# %%
s[0] #forward indexing
# Out:
# 'h'

# %%
s[-5] #backward indexing
# Out:
# 'w'

# %%
s
# Out:
# 'hello world'

# %%
s[10]
# Out:
# 'd'

# %%
s[:5]
# Out:
# 'hello'

# %%
s[5:]
# Out:
# ' world'

# %%
s[8:]
# Out:
# 'rld'

# %%
s
# Out:
# 'hello world'

# %%
s[::-1]
# Out:
# 'dlrow olleh'

# %%
s[::-5]
# Out:
# 'd h'

# %%
s[2:10:2]
# Out:
# 'lowr'

# %%
s
# Out:
# 'hello world'

# %%
s[2:10:2]
# Out:
# 'lowr'

# %%
s1 = "Hello"
s2 = "Python"
s3 = s1 + s2
print(s3)
# Out:
# HelloPython
